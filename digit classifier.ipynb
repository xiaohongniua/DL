# %% [markdown]
# # whenever you want to use deeplearning here are some To do list
# ## 1.Check if it is a problem where Neural Network gives you uplift over traditional algorithms(refer to the checklist in the section above)
# ## 2.Do a survey of which Neural Network architecture is most suitable for the required problem
# ## 3.Define Neural Network architecture through whichever language / library you choose.
# ## 4.Convert data to right format and divide it in batches
# ## 5.Pre-process the data according to your needs
# ## 6.Augment Data to increase size and make better trained models
# ## 7.Feed batches to Neural Network
# ## 8.Train and monitor changes in training and validation data sets
# ## 9.Test your model, and save it for future use

# %%
import tensorflow as tf
import tflearn
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-f0d83b41d5e6> in <module>()
#       1 import tensorflow as tf
# ----> 2 import tflearn
#
# ImportError: No module named 'tflearn'

# %% [markdown]
# # STEP1: Data load and preprocess

# %%
import tflearn.datasets.mnist as mnist
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-7a37a63f3daa> in <module>()
# ----> 1 import tflearn.datasets.mnist as mnist
#
# ImportError: No module named 'tflearn'
